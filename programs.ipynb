# %% [markdown]
# **Program 1**
#
# Write a python program to print "Hello Python".

# %%
print("Hello Python")
# Out:
# Hello Python

# %% [markdown]
# **Program 2**
#
# Write a python program to do arthmetical op(add)

# %%
# num1 = float(input("Enter number 1: "))
# num2 = float(input("Enter number 2: "))
sum_result = num1 + num2
print(f"sum: {num1} + {num2} = {sum_result}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 num1 = float(input("Enter number 1: "))
#       2 num2 = float(input("Enter number 2: "))
#       3 sum_result = num1 + num2
#
# ValueError: could not convert string to float: ''

# %% [markdown]
# **Program 3**
#
# Write a python program to find area of triangle

# %%
# input base and height from user
base = float(input("Enter base of the triangle: "))
